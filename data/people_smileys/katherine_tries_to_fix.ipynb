# %%
import json
import os 
import urllib 
import re 
import requests 
import tweepy  
import gender_guesser.detector as gender         
import datetime
from time import gmtime, strftime
from textblob import TextBlob 
        
     
consumerKey =  "UubTIUOSDbsaETbSm4UdYk3mk"
consumerSecret = "f1RgFT5UaqhxQYiYr4aoCTppNMIwJpE0zMSWkPzsu8N7bIGjnM"
accessToken = "1718802966-aC0aukGfO6v58GQe5K2z5XSirddJ22Iw2qfnFJE"
accessTokenSecret = "bbVkfnmrozQSYJRraQC7EKjcs9Pdl39OIaMkiQHQiF28F"
  
   
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)  
auth.set_access_token(accessToken, accessTokenSecret)  
  

api = tweepy.API(auth, wait_on_rate_limit=True)  
  
print("it is running")

with open('../../emoji-subtable/people_and_smileys.json', encoding='utf-8') as f:
    raw = json.load(f)

final_tweets = []
emoji_list = raw['emoji']
# emoji_list = emoji_list[0]

# count = 0

########### currently I have the correctly formatted versions of 0 -120
## and now we just need 120-beyond this goes 120-200
for e in emoji_list:
    emoji = e['emoji']   
    final_tweets.append([emoji])
    last = final_tweets[-1]        
    try:
        tweet_obj_list=[]
        print(emoji)
        for tweet in tweepy.Cursor(api.search,q = emoji,tweet_mode='extended').items(15):    
            tweet_obj = []
            content = tweet.full_text
            content = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", content).split()) 
            analysis = TextBlob(content) 
            # set sentiment 
            if analysis.sentiment.polarity > 0: 
                sentiment = 'positive'
            elif analysis.sentiment.polarity == 0: 
                sentiment = 'neutral'
            else: 
                sentiment = 'negative'
                
            tweet_obj.append({
                'id': tweet.id,
                'text': tweet.full_text,
                'sentiment': sentiment,
                'user_id': tweet.user.id,
                'name': tweet.user.screen_name,
                'location': tweet.user.location,
                'retweet count': tweet.retweet_count,
                'favorite count': tweet.favorite_count,
                'time': tweet.created_at.strftime('%m/%d/%Y %H:%M:%S'),
                'lang': tweet.user.lang
                })
            tweet_obj_list.append(tweet_obj)
    except:
        print('error on: ' + query)
    last.append(tweet_obj_list)
#     count = count + 1
    
#     if (count == 1): 
#         break
    
    
## writes to this
    
with open('people_and_smileys-03-27.json', 'w', encoding='utf-8') as outfile:  
    json.dump(final_tweets, outfile, ensure_ascii=False, indent=4, separators=(',', ': ')) 
    
print("done")
# Out:
# it is running
# 🌱
# 🌲
# 🌳
# 🌴
# 🌵
# 🌷
# 🌸
# 🌹
# 🌺
# 🌻
# 🌼
# 🌾
# 🌿
# 🍀
# 🍁
# 🍂
# 🍃
# 🐀
# 🐁
# 🐂
# 🐃
# 🐄
# 🐅
# 🐆
# 🐇
# 🐈
# 🐉
# 🐊
# 🐋
# 🐌
# 🐍
# 🐎
# 🐏
# 🐐
# 🐑
# 🐒
# 🐓
# 🐔
# 🐕
# 🐖
# 🐗
# 🐘
# 🐙
# 🐚
# 🐛
# 🐜
# 🐝
# 🐞
# 🐟
# 🐠
# 🐡
# 🐢
# 🐣
# 🐤
# 🐥
# 🐦
# 🐧
# 🐨
# 🐩
# 🐪
# 🐫
# 🐬
# 🐭
# 🐮
# 🐯
# 🐰
# 🐱
# 🐲
# 🐳
# 🐴
# 🐵
# 🐶
# 🐷
# 🐸
# 🐹
# 🐺
# 🐻
# 🐼
# 🐽
# 🐾
# 💐
# 💮
# 🥀
# 🦀
# 🦁
# 🦂
# 🦃
# 🦄
# 🦅
# 🦆
# 🦇
# 🦈
# 🦉
# 🦊
# 🦋
# 🦌
# 🦍
# 🦎
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ...
