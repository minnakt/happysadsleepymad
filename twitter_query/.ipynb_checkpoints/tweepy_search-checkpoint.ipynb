# %%
import json
import os 
import urllib 
import re 
import requests 
import tweepy  
import gender_guesser.detector as gender         
import datetime
from time import gmtime, strftime
import nltk.data
from textblob import TextBlob 

        
     
consumerKey =  # KEY OMITTED #
consumerSecret = # KEY OMITTED #
accessToken = # KEY OMITTED #
accessTokenSecret = # KEY OMITTED #
  
   
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)  
auth.set_access_token(accessToken, accessTokenSecret)  
  

api = tweepy.API(auth, wait_on_rate_limit=True)  
  

with open('insert desired json file here', encoding='utf-8') as f:
    raw = json.load(f)

final_tweets = []
emoji_list = raw['emoji']

for e in emoji_list:
    emoji = e['emoji']   
    final_tweets.append([emoji])
    last = final_tweets[-1]        
    try:
        tweet_obj_list=[]
        print(emoji)
        for tweet in tweepy.Cursor(api.search,q = emoji,tweet_mode='extended').items(15):    
            tweet_obj = []
            content = tweet.full_text
            content = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", content).split()) 
            analysis = TextBlob(content) 
            # set sentiment 
            if analysis.sentiment.polarity > 0: 
                sentiment = 'positive'
            elif analysis.sentiment.polarity == 0: 
                sentiment = 'neutral'
            else: 
                sentiment = 'negative'
                
            tweet_obj.append({
                'id': tweet.id,
                'text': tweet.full_text,
                'sentiment': sentiment,
                'user_id': tweet.user.id,
                'name': tweet.user.screen_name,
                'location': tweet.user.location,
                'retweet count': tweet.retweet_count,
                'favorite count': tweet.favorite_count,
                'time': tweet.created_at.strftime('%m/%d/%Y %H:%M:%S'),
                'lang': tweet.user.lang
                })
            tweet_obj_list.append(tweet_obj)
    except:
        print('error on: ' + query)
    last.append(tweet_obj_list)
    
with open('food_and_drink_04-12.json', 'w', encoding='utf-8') as outfile:  
    json.dump(final_tweets, outfile, ensure_ascii=False, indent=4, separators=(',', ': '))
# Out:
# 🌭
# 🌮
# 🌯
# 🌰
# 🌽
# 🍄
# 🍅
# 🍆
# 🍇
# 🍈
# 🍉
# 🍊
# 🍋
# 🍌
# 🍍
# 🍎
# 🍏
# 🍐
# 🍑
# 🍒
# 🍓
# 🍔
# 🍕
# 🍖
# 🍗
# 🍘
# 🍙
# 🍚
# 🍛
# 🍜
# 🍝
# 🍞
# 🍟
# 🍠
# 🍡
# 🍢
# 🍣
# 🍤
# 🍥
# 🍦
# 🍧
# 🍨
# 🍩
# 🍪
# 🍫
# 🍬
# 🍭
# 🍮
# 🍯
# 🍰
# 🍱
# 🍲
# 🍳
# 🍴
# 🍵
# 🍶
# 🍷
# 🍸
# 🍹
# 🍺
# 🍻
# 🍼
# 🍾
# 🍿
# 🎂
# 🏺
# 🔪
# 🥂
# 🥃
# 🥄
# 🥐
# 🥑
# 🥒
# 🥓
# 🥔
# 🥕
# 🥖
# 🥗
# 🥘
# 🥙
# 🥚
# 🥛
# 🥜
# 🥝
# 🥞
# 🥟
# 🥠
# 🥡
# 🥢
# 🥣
# 🥤
# 🥥
# 🥦
# 🥧
# 🥨
# 🥩
# 🥪
# 🥫
# 🧀
# ☕
